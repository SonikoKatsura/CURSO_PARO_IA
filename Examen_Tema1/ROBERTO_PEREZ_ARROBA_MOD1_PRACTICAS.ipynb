# %% [markdown]
# ![image.png](attachment:5a6cab63-675b-49c1-89b2-b2a2f13ad2dd.png)![image.png](attachment:92590771-c4d3-43dc-8407-bc3daba306a7.png)

# %% [markdown]
# # EXAMEN PRÁCTICO: MÓDULO 1

# %% [markdown]
# ## PANDAS

# %% [markdown]
# ## Pregunta 1: Carga y comprobación.
#
# Para hacer la parte de pandas usaremos el archivo **"house_price.csv"** que se descargará de la plataforma y se subirá donde está el notebook del examen antes de que empiece el propio examen.
#
# En este dataset se presenta información sobre las características de unas viviendas y su precio. El significado de cada uno de los campos es el siguiente:
#
# - **id**: campo único identificativo (no tiene otra función)
# - **price**: precio actual estimado de la vivienda (dólares)
# - **bedrooms**: nº de dormitorios de la vivienda
# - **bathrooms**: nº de baños de la vivienda (atención a comentario del docente)
# - **sqft_living**: superficie "habitable" de la vivienda (casa, mansión etc. únicamente) en pies al cuadrado
# - **sqft_lot**: superficie total de la propiedad (vivienda + jardín patio etc ...) en pies al cuadrado
# - **floors**: nº de plantas de la vivienda (atención a comentario del docente)
# - **waterfront**: si tiene o no vistas al mar, río o lago ("codificado" numérico, un uno (1) si lo tiene y un cero (0) si no)
# - **yr_built**: año de construcción de la vivienda
# - **yr_renovated**: año de la última reforma
# - **zipcode**: código postal (a meros efectos de identificar la zona)

# %% [markdown]
# \

# %% [markdown]
# a) **Antes de seguir en este notebook**, abran el archivo como texto plano para echar un vistazo (recuerden que se hace clickando botón derecho sobre el nombre del archivo en la ventana del Explorador de Archivos y clickando en el menú emergente en la opción "Abrir con" ---> "Bloc de notas"). Respondan a las siguientes preguntas (**escriban como texto sus respuestas, no código**):
#
# - ¿El archivo tiene cabecera? ¿Está en el lugar adecuado?
#    *(Puntuación: 0.20 ptos)*
# - ¿Le sigue a la cabecera los datos? ¿Por cuál caracter están separados los datos de las columnas en cada fila?
#    *(Puntuación: 0.20 ptos)*

# %% [markdown]
# b) Trabajando ya en este notebook, importa las librerias necesarias y carga los datos del archivo en un Dataframe. Comprueba la carga mostrando sólo algunas filas del DataFrame (del principio, del final o aleatorio (muestra), todas son válidas, usad sólo una)
#
# *(Puntuación: 1 ptos)*

# %%
import numpy as np
import pandas as pd


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# c) Obtengan **información general del DataFrame** mediante el **uso de los dos métodos que ustedes conocen** (escriban el código).
#
# *(Puntuación: 0.40 ptos)*

# %%
## código

# %% [markdown]
# Fijándose en **el resultado que devuelven las dos** respondan a las siguientes preguntas **(como texto)**:
#
# - ¿Cuantas filas y columnas tiene?
#    *(Puntuación: 0.10 ptos)*
# - ¿Existen elementos nulos? En caso afirmativo señalar en cuáles columnas
#    *(Puntuación: 0.10 ptos)*
# - ¿Cuál es la media ("mean") del precio de las viviendas? NO confundir con la mediana (50%)
#    *(Puntuación: 0.10 ptos)*
# - ¿Cuál es el año de construcción de la vivienda más antigua?
#    *(Puntuación: 0.10 ptos)*
# - ¿Cuál es la superficie de vivienda más grande, con mayor superficie "habitable" (NO el de toda la propiedad)?
#    *(Puntuación: 0.10 ptos)*
#
#  Recuerden que tienen **el significado de las columnas al principio de la pregunta** por si las necesitan

# %% [markdown]
# ## Pregunta 2: Limpieza, corregir datos de una columna.
#
# Queremos que la **columna "waterfront"** en vez de mostrar "números" (así estaba codificada de origen) se mas "explicativa", muestre como valores texto.
#
# Para ello se deberán remplazar sus valores **en la columna**:
# - donde ponga un cero (0) remplazarlo por ("Sin vistas") como cadena.
# - donde ponga un uno (1) remplazarlo por ("Con vistas") como cadena.
#
# Escriban el código correspondiente para hacer esta acción.
#
# *(Puntuación: 1 ptos)*

# %%
## CÓDIGO

# %% [markdown]
# ## Pregunta 3: Transformación, cálculos con columnas.
#
# Queremos expresar las **columnas "sqft_living" y "sqft_lot"** en metros cuadrados (en vez de pies cuadrados, como viene de origen). El factor de conversión es 0.0929 metros cuadrados por cada pie cuadrado.
#
# Calculen las nuevas columnas y asignenlas ("pisen") las primeras.
#
# **NOTA**: como se tratan de 2 columnas lo pueden hacer de dos maneras:
# - con cierto método que aplica el mismo cambio a esas 2 columnas al mismo tiempo.  *(Puntuación: 1'5 ptos sobre 1'50 ptos de la pregunta)*
#
# - también se pueden hacer una a una de manera "manual" operando matemáticamente una a una.  *(Puntuación: 0.75 ptos sobre 1'50 ptos de la pregunta)*
#
# Escriban el código correspondiente para hacer esta acción (un camino u otro, NO los 2).

# %%
## CÓDIGO

# %% [markdown]
# ## Pregunta 4: Responder a preguntas mediante agregación.
#
# Se pide responder a las siguientes preguntas mediante el **uso de agrupamiento y agregados por dicho agrupamiento**. Deben **escribir el código correspondiente que devuelva los resultados** que permitan responder a la pregunta, **y a partir de esos resultados contestar.**
#
#
# - ¿Influye de manera determinante la zona (columna "zipcode") en el precio de la vivienda? Utiliza la media del precio para valorarlo.  *(Puntuación: 0.60 ptos)*
#
# - ¿Influye de manera determinante si la vivienda tiene vistas al mar, río, etc (columna "waterfront") en el precio de la vivienda? Utiliza la media del precio para valorarlo  *(Puntuación: 0.60 ptos)*
#
# - Devuelve por zona (columna "zipcode") el  máximo y mínimo de las columnas 'price' y 'sqft_lot' (solo mostrarlas, en este apartado no hay pregunta que contestar)  *(Puntuación: 1 ptos)*
#
#
# Escriban el código correspondiente y con su resultado contesten a las preguntas (atentos a la indicación del docente)

# %%
## CÓDIGO

# %% [markdown]
# ## Pregunta 5:
#
# a) Nos interesa visualizar las dos superficies, el nº de dormitorios y baños y el precio de las casas que se renovaron del 2010 en adelante. Escribe la selección, el código adecuado para mostrarlas (solo mostrarlas, no hay que guardarlas)
# *(Puntuación: 1.5 ptos)*

# %% [markdown]
# b) El jefe de equipo finalmente decide que eliminemos las columnas **"yr_built"** y **"yr_renovated"** y que NUNCA las vamos a necesitar. Escribe el código más eficiente y ejecutalo
# *(Puntuación: 1 ptos)*

# %% [markdown]
# c) Por ultimo vamos a guardar el dataframe en disco (local o GOOGLE DRIVE). Escribe el código necesario
# *(Puntuación: 0.5 ptos)*
