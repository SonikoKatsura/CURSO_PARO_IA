# %% [markdown]
# # 🐼 Ejercicios de Pandas - Curso de Python para Ciencia de Datos
#
# Este notebook contiene 20 ejercicios diseñados para practicar el uso de la biblioteca `pandas`, organizados de menor a mayor complejidad. Asegúrate de importar `pandas` y cargar el conjunto de datos necesario antes de comenzar cada ejercicio.
#
# ---
#
# ## 📦 Preparación
# ```python
# import pandas as pd
#
# # Puedes usar el siguiente dataset como base:
# df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# ```
#
# ---
#
# ¡Buena suerte! 💪 Recuerda usar `df.head()`, `df.shape`, y `df.columns` para orientarte siempre que lo necesites.

# %% [markdown]
# ### 🧪 Nivel 1: Exploración de datos
#
# 1. **Carga el archivo CSV y muestra las primeras 5 filas.**
#
# 2. **Muestra las últimas 10 filas del DataFrame.**
#
# 3. **Usa `.info()` para obtener información general del DataFrame.**
#
# 4. **Utiliza `.describe()` para ver estadísticas descriptivas de las columnas numéricas.**
#
# 5. **Muestra los nombres de las columnas y los tipos de datos de cada una.**
#
# ---

# %%
import pandas as pd

# Puedes usar el siguiente dataset como base:
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

print("1. Primeras 5 filas del DataFrame:\n")
df.head()
# Out:
# 1. Primeras 5 filas del DataFrame:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
print("2. Últimas 10 filas del DataFrame:\n")
df.tail(10)
# Out:
# 2. Últimas 10 filas del DataFrame:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
print("3. Información general del DataFrame (.info()):\n")
df.info()
# Out:
# 3. Información general del DataFrame (.info()):
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print("4. Estadísticas descriptivas de las columnas numéricas):\n")
df.describe()
# Out:
# 4. Estadísticas descriptivas de las columnas numéricas):
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print("5. Nombres de las columnas y tipos de datos:\n")
df.dtypes
# Out:
# 5. Nombres de las columnas y tipos de datos:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ---
#
# ### 🧪 Nivel 2: Selección y filtrado de datos
#
# 6. **Selecciona solo la columna "Name" del DataFrame.**
#
# 7. **Selecciona las columnas "Name" y "Age".**
#
# 8. **Selecciona las primeras 10 filas usando `.iloc[]`.**
#
# 9. **Filtra a los pasajeros mayores de 60 años.**
#
# 10. **Filtra a los pasajeros que viajaban en primera clase y eran mujeres.**
#
# ---

# %%
# 6. Selecciona solo la columna "Name" del DataFrame.
nombres = df['Name']
print("6. Columna 'Name':\n")
nombres.head()
# Out:
# 6. Columna 'Name':
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
# 7. Selecciona las columnas "Name" y "Age".
nombre_edad = df[['Name', 'Age']]
print("\n7. Columnas 'Name' y 'Age':\n")
nombre_edad.head()
# Out:
# 7. Columnas 'Name' y 'Age':
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
# 8. Selecciona las primeras 10 filas usando .iloc[].
print("\n8. Primeras 10 filas (.iloc[0:10]):\n")
df.iloc[0:10]
# Out:
# 8. Primeras 10 filas (.iloc[0:10]):
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# 9. Filtra a los pasajeros mayores de 60 años.
mayores_60 = df[df['Age'] > 60]
print("9. Pasajeros mayores de 60 años:\n")
mayores_60.head()
# Out:
# 9. Pasajeros mayores de 60 años:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 96            97         0       1       Goldschmidt, Mr. George B  male
# 116          117         0       3            Connors, Mr. Patrick  male
# 170          171         0       1       Van der hoef, Mr. Wyckoff  male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   66.0      0      0  C.A. 24579  10.5000   NaN        S
# 54   65.0      0      1      113509  61.9792   B30        C
# 96   71.0      0      0    PC 17754  34.6542    A5        C
# 116  70.5      0      0      370369   7.7500   NaN        Q
# 170  61.0      0      0      111240  33.5000   B19        S

# %%
# 10. Filtra a los pasajeros que viajaban en primera clase y eran mujeres.
primera_clase_mujeres = df[(df['Pclass'] == 1) & (df['Sex'] == 'female')]
print("\n10. Pasajeros de primera clase que eran mujeres:\n")
primera_clase_mujeres.head()
# Out:
# 10. Pasajeros de primera clase que eran mujeres:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 11           12         1       1
# 31           32         1       1
# 52           53         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
#
#     Parch    Ticket      Fare Cabin Embarked
# 1       0  PC 17599   71.2833   C85        C
# 3       0    113803   53.1000  C123        S
# 11      0    113783   26.5500  C103        S
# 31      0  PC 17569  146.5208   B78        C
# ...

# %% [markdown]
# ---
#
# ### 🧪 Nivel 3: Limpieza de datos
#
# 11. **Cuenta cuántos valores nulos hay en cada columna.**
#
# 12. **Elimina todas las filas donde falte el valor de "Age".**
#
# 13. **Rellena los valores faltantes en "Embarked" con el valor más frecuente.**
#
# 14. **Crea una nueva columna "EdadRedondeada" que contenga la edad redondeada.**
#
# 15. **Reemplaza los valores de la columna "Sex" por "Hombre" y "Mujer".**
#
# ---

# %%
# 11. Cuenta cuántos valores nulos hay en cada columna.
print("11. Número de valores nulos por columna:\n")
df.isnull().sum()
# Out:
# 11. Número de valores nulos por columna:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# 12. Elimina todas las filas donde falte el valor de "Age".

# Mostrar el número de filas antes de la eliminación
filas_antes = df.shape[0]
print("\n12. Eliminando filas con valores nulos en 'Age':")
print(f"Número de filas en el DataFrame original: {filas_antes}")
print("\nSample filas del DataFrame original (con posibles nulos en 'Age'):")
print(df[['Age']].sample(10))

# Eliminar las filas con valores nulos en "Age"
df_sin_nulos_edad = df.dropna(subset=['Age']).copy()

# Mostrar el número de filas después de la eliminación
filas_despues = df_sin_nulos_edad.shape[0]
print(f"\nNúmero de filas después de eliminar los nulos en 'Age': {filas_despues}")
print("\nSample filas del DataFrame después de eliminar los nulos en 'Age':")
print(df_sin_nulos_edad[['Age']].sample(10))
# Out:
# 12. Eliminando filas con valores nulos en 'Age':
# Número de filas en el DataFrame original: 891
#
# Sample filas del DataFrame original (con posibles nulos en 'Age'):
#       Age
# 815   NaN
# 31    NaN
# 274   NaN
# 130  33.0
# 577  39.0
# 191  19.0
# 481   NaN
# 595  36.0
# 672  70.0
# 33   66.0
#
# Número de filas después de eliminar los nulos en 'Age': 714
#
# Sample filas del DataFrame después de eliminar los nulos en 'Age':
#       Age
# 167  45.0
# 590  35.0
# 567  29.0
# 20   35.0
# 24    8.0
# 685  25.0
# 62   45.0
# 279  35.0
# 645  48.0
# 700  18.0

# %%
# 13. Rellena los valores faltantes en "Embarked" con el valor más frecuente.

# Mostrar número de nulos antes
print("\n13. Rellenando valores nulos en 'Embarked':")
print(f"Número de nulos en 'Embarked' antes del relleno: {df_sin_nulos_edad['Embarked'].isnull().sum()}")
print("\nSample filas del DataFrame antes del relleno de 'Embarked':")
print(df_sin_nulos_edad[['Embarked']].sample(10))

# Calcular el valor más frecuente
valor_mas_frecuente_embarked = df_sin_nulos_edad['Embarked'].mode()[0]

# Rellenar los valores faltantes (manera recomendada)
df_sin_nulos_edad['Embarked'] = df_sin_nulos_edad['Embarked'].fillna(valor_mas_frecuente_embarked)

# Mostrar número de nulos después
print(f"\nNúmero de nulos en 'Embarked' después del relleno: {df_sin_nulos_edad['Embarked'].isnull().sum()}")
print("\nSamples filas del DataFrame después del relleno de 'Embarked':")
print(df_sin_nulos_edad[['Embarked']].sample(10))
# Out:
# 13. Rellenando valores nulos en 'Embarked':
# Número de nulos en 'Embarked' antes del relleno: 2
#
# Sample filas del DataFrame antes del relleno de 'Embarked':
#     Embarked
# 646        S
# 688        S
# 136        S
# 433        S
# 820        S
# 289        Q
# 280        Q
# 319        C
# 694        S
# 164        S
#
# Número de nulos en 'Embarked' después del relleno: 0
#
# Samples filas del DataFrame después del relleno de 'Embarked':
#     Embarked
# 774        S
# 232        S
# 744        S
# 532        C
# 183        S
# 575        S
# 847        C
# 607        S
# 708        S
# 580        S

# %%
# 14. Crea una nueva columna "EdadRedondeada" que contenga la edad redondeada.
df_sin_nulos_edad['EdadRedondeada'] = df_sin_nulos_edad.Age.round().astype(int)
print("\n14. DataFrame con la nueva columna 'EdadRedondeada':")
df_sin_nulos_edad[['Age', 'EdadRedondeada']].sample(10)
# Out:
# 14. DataFrame con la nueva columna 'EdadRedondeada':
#       Age  EdadRedondeada
# 829  62.0              62
# 14   14.0              14
# 728  25.0              25
# 263  40.0              40
# 799  30.0              30
# 638  41.0              41
# 88   23.0              23
# 179  36.0              36
# 307  17.0              17
# 789  46.0              46

# %%
# 15. Reemplaza los valores de la columna "Sex" por "Hombre" y "Mujer".
df_sin_nulos_edad['Sex'].replace({'male': 'Hombre', 'female': 'Mujer'}, inplace=True)
print("\n15. DataFrame con los valores de 'Sex' reemplazados (muestra aleatoria):")
df_sin_nulos_edad[['PassengerId', 'Name', 'Sex']].sample(10)
# Out:
# 15. DataFrame con los valores de 'Sex' reemplazados (muestra aleatoria):
# <ipython-input-16-a77b7824e846>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_nulos_edad['Sex'].replace({'male': 'Hombre', 'female': 'Mujer'}, inplace=True)
#      PassengerId                                               Name     Sex
# 558          559             Taussig, Mrs. Emil (Tillie Mandelbaum)   Mujer
# 498          499    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   Mujer
# ...

# %% [markdown]
# ---
#
# ### 🧪 Nivel 4: Agrupamiento y análisis
#
# 16. **Cuenta cuántos pasajeros hay por clase (Pclass).**
#
# 17. **Calcula la media de edad por clase de pasajero.**
#
# 18. **Agrupa por "Sex" y "Pclass" y muestra la tarifa media pagada ("Fare").**
#
# 19. **Agrupa por "Embarked" y muestra cuántos sobrevivieron en cada puerto de embarque.**
#
# 20. **Crea una tabla pivote que muestre la media de edad según el sexo y la clase ("Pclass").**
#
# ---

# %%
# 16. Cuenta cuántos pasajeros hay por clase (Pclass).
print("\n16. Número de pasajeros por clase (Pclass):\n")
df_sin_nulos_edad['Pclass'].value_counts()
# Out:
# 16. Número de pasajeros por clase (Pclass):
# Pclass
# 3    355
# 1    186
# 2    173
# Name: count, dtype: int64

# %%
# 16. Cuenta cuántos pasajeros hay por clase (Pclass).
print("\n16. % de pasajeros por clase (Pclass):\n")
df_sin_nulos_edad['Pclass'].value_counts(normalize=True)*100
# Out:
# 16. % de pasajeros por clase (Pclass):
# Pclass
# 3    49.719888
# 1    26.050420
# 2    24.229692
# Name: proportion, dtype: float64

# %%
# 17. Calcula la media de edad por clase de pasajero.
print("\n17. Media de edad por clase de pasajero:\n")
df_sin_nulos_edad.groupby('Pclass').Age.mean()
# Out:
# 17. Media de edad por clase de pasajero:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
# 18. Agrupa por "Sex" y "Pclass" y muestra la tarifa media pagada ("Fare").
print("\n18. Tarifa media pagada por sexo y clase:\n")
df_sin_nulos_edad.groupby(['Sex', 'Pclass'])['Fare'].mean()
# Out:
# 18. Tarifa media pagada por sexo y clase:
# Sex     Pclass
# Hombre  1          71.142781
#         2          21.113131
#         3          12.162695
# Mujer   1         107.946275
#         2          21.951070
#         3          15.875369
# Name: Fare, dtype: float64

# %%
# 19. Agrupa por "Embarked" y muestra cuántos sobrevivieron en cada puerto de embarque.
print("\n19. Número de sobrevivientes por puerto de embarque:\n")
df_sin_nulos_edad.groupby('Embarked')['Survived'].sum()
# Out:
# 19. Número de sobrevivientes por puerto de embarque:
# Embarked
# C     79
# Q      8
# S    203
# Name: Survived, dtype: int64

# %%
# 20. Crea una tabla pivote que muestre la media de edad según el sexo y la clase ("Pclass").
tabla_pivot_edad = df_sin_nulos_edad.pivot_table(values='Age', index='Sex', columns='Pclass')
print("\n20. Tabla pivote de la media de edad por sexo y clase:\n")
tabla_pivot_edad
# Out:
# 20. Tabla pivote de la media de edad por sexo y clase:
# Pclass          1          2          3
# Sex
# Hombre  41.281386  30.740707  26.507589
# Mujer   34.611765  28.722973  21.750000
